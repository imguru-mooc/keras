# %% [markdown]
# #### 검증 세트를 이용한 과대적합 찾기

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
cancer = load_breast_cancer()
x = cancer.data
y = cancer.target
x_train_all, x_test, y_train_all, y_test = train_test_split(x, y, stratify=y, 
                                                            test_size=0.2, random_state=42)
x_train, x_val, y_train, y_val = train_test_split(x_train_all, y_train_all, stratify=y_train_all, 
                                                  test_size=0.2, random_state=42)

# %%
print(x_train.shape)
# Out:
# (364, 30)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train)
x_train_scaled = scaler.transform(x_train)
x_val_scaled = scaler.transform(x_val)

# %%
class SingleLayer:
    
    def __init__(self, learning_rate=0.1):
        self.w = None
        self.b = None
        self.losses = []
        self.val_losses = []
        self.w_history = []
        self.lr = learning_rate

    def forpass(self, x):
        z = np.sum(x * self.w) + self.b    # 직선 방정식을 계산합니다
        return z

    def backprop(self, x, err):
        w_grad = x * err          # 가중치에 대한 그래디언트를 계산합니다
        b_grad = 1 * err    # 절편에 대한 그래디언트를 계산합니다
        return w_grad, b_grad

    def activation(self, z):
        z = np.clip(z, -100, None) # 안전한 np.exp() 계산을 위해
        a = 1 / (1 + np.exp(-z))  # 시그모이드 계산
        return a
        
    def fit(self, x, y, epochs=100, x_val=None, y_val=None):
        self.w = np.ones(x.shape[1])               # 가중치를 초기화합니다.
        self.b = 0                                 # 절편을 초기화합니다.
        self.w_history.append(self.w.copy())       # 가중치를 기록합니다.
        np.random.seed(42)                         # 랜덤 시드를 지정합니다.
        for i in range(epochs):                    # epochs만큼 반복합니다.
            loss = 0
            # 인덱스를 섞습니다
            indexes = np.random.permutation(np.arange(len(x)))
            for i in indexes:                      # 모든 샘플에 대해 반복합니다
                z = self.forpass(x[i])             # 정방향 계산
                a = self.activation(z)             # 활성화 함수 적용
                err = (a - y[i])                  # 오차 계산
                w_grad, b_grad = self.backprop(x[i], err) # 역방향 계산
                self.w -= self.lr * w_grad         # 가중치 업데이트
                self.b -= b_grad                   # 절편 업데이트
                # 가중치를 기록합니다.
                self.w_history.append(self.w.copy())
                # 안전한 로그 계산을 위해 클리핑한 후 손실을 누적합니다
                a = np.clip(a, 1e-10, 1-1e-10)
                loss += -(y[i]*np.log(a)+(1-y[i])*np.log(1-a))
            # 에포크마다 평균 손실을 저장합니다
            self.losses.append(loss/len(y))
            # 검증 세트에 대한 손실을 계산합니다
            self.update_val_loss(x_val, y_val)
    
    def predict(self, x):
        z = [self.forpass(x_i) for x_i in x]     # 정방향 계산
        return np.array(z) >= 0                   # 스텝 함수 적용
    
    def score(self, x, y):
        return np.mean(self.predict(x) == y)
    
    
    def update_val_loss(self, x_val, y_val):
        if x_val is None:
            return
        val_loss = 0
        for i in range(len(x_val)):
            z = self.forpass(x_val[i])     # 정방향 계산
            a = self.activation(z)         # 활성화 함수 적용
            a = np.clip(a, 1e-10, 1-1e-10)
            val_loss += -(y_val[i]*np.log(a)+(1-y_val[i])*np.log(1-a))
        self.val_losses.append(val_loss/len(y_val))

# %%
layer3 = SingleLayer()
layer3.fit(x_train_scaled, y_train, x_val=x_val_scaled, y_val=y_val)
plt.ylim(0, 0.3)
plt.plot(layer3.losses)
plt.plot(layer3.val_losses)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train_loss', 'val_loss'])
plt.show()

# %% [markdown]
# ### 케라스에 검증 데이터 사용하기

# %%
from tensorflow.keras.models import Sequential # 케라스의 Sequential()을 임포트
from tensorflow.keras.layers import Dense      # 케라스의 Dense()를 임포트
from tensorflow.keras import optimizers        # 케라스의 옵티마이저를 임포트
import numpy as np # Numpy를 임포트
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers.experimental import preprocessing

cancer = load_breast_cancer()

x = cancer.data
y = cancer.target

x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, 
test_size=0.2, random_state=42)

layer = preprocessing.Normalization()
layer.adapt(x_train) # 메서드를 통해 전처리 레이어의 상태를 훈련 데이터에 노출함으로써 상태를 설정할 수 있습니다.

model=Sequential()
model.add(layer)
model.add(Dense(1, input_dim=30, activation='sigmoid'))
SGD=optimizers.SGD(learning_rate=0.01)
model.compile(optimizer=SGD ,loss='binary_crossentropy',metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=1, epochs=100, shuffle=True, validation_split=0.2)

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train_loss', 'val_loss'])
plt.show()
# Out:
# Epoch 1/100
# 364/364 [==============================] - 0s 803us/step - loss: 0.2353 - accuracy: 0.9258 - val_loss: 0.1460 - val_accuracy: 0.9560
# Epoch 2/100
# 364/364 [==============================] - 0s 705us/step - loss: 0.1347 - accuracy: 0.9615 - val_loss: 0.1129 - val_accuracy: 0.9560
# Epoch 3/100
# 364/364 [==============================] - 0s 680us/step - loss: 0.1123 - accuracy: 0.9670 - val_loss: 0.0990 - val_accuracy: 0.9670
# Epoch 4/100
# 364/364 [==============================] - 0s 677us/step - loss: 0.1002 - accuracy: 0.9725 - val_loss: 0.0914 - val_accuracy: 0.9670
# Epoch 5/100
# 364/364 [==============================] - 0s 667us/step - loss: 0.0933 - accuracy: 0.9725 - val_loss: 0.0851 - val_accuracy: 0.9780
# Epoch 6/100
# 364/364 [==============================] - 0s 675us/step - loss: 0.0881 - accuracy: 0.9753 - val_loss: 0.0802 - val_accuracy: 0.9780
# Epoch 7/100
# 364/364 [==============================] - 0s 663us/step - loss: 0.0842 - accuracy: 0.9753 - val_loss: 0.0762 - val_accuracy: 0.9780
# Epoch 8/100
# 364/364 [==============================] - 0s 662us/step - loss: 0.0811 - accuracy: 0.9780 - val_loss: 0.0737 - val_accuracy: 0.9890
# Epoch 9/100
# 364/364 [==============================] - 0s 704us/step - loss: 0.0785 - accuracy: 0.9780 - val_loss: 0.0713 - val_accuracy: 0.9890
# Epoch 10/100
# 364/364 [==============================] - 0s 670us/step - loss: 0.0765 - accuracy: 0.9780 - val_loss: 0.0697 - val_accuracy: 0.9890
# Epoch 11/100
# 364/364 [==============================] - 0s 694us/step - loss: 0.0747 - accuracy: 0.9780 - val_loss: 0.0679 - val_accuracy: 0.9890
# Epoch 12/100
# 364/364 [==============================] - 0s 702us/step - loss: 0.0731 - accuracy: 0.9780 - val_loss: 0.0666 - val_accuracy: 0.9890
# Epoch 13/100
# 364/364 [==============================] - 0s 678us/step - loss: 0.0717 - accuracy: 0.9835 - val_loss: 0.0650 - val_accuracy: 0.9890
# Epoch 14/100
# 364/364 [==============================] - 0s 695us/step - loss: 0.0705 - accuracy: 0.9835 - val_loss: 0.0637 - val_accuracy: 0.9890
# Epoch 15/100
# 364/364 [==============================] - 0s 720us/step - loss: 0.0694 - accuracy: 0.9863 - val_loss: 0.0626 - val_accuracy: 0.9890
# Epoch 16/100
# 364/364 [==============================] - 0s 681us/step - loss: 0.0684 - accuracy: 0.9808 - val_loss: 0.0620 - val_accuracy: 0.9890
# Epoch 17/100
# 364/364 [==============================] - 0s 683us/step - loss: 0.0675 - accuracy: 0.9808 - val_loss: 0.0613 - val_accuracy: 0.9890
# Epoch 18/100
# 364/364 [==============================] - 0s 685us/step - loss: 0.0667 - accuracy: 0.9863 - val_loss: 0.0607 - val_accuracy: 0.9890
# Epoch 19/100
# 364/364 [==============================] - 0s 685us/step - loss: 0.0659 - accuracy: 0.9890 - val_loss: 0.0602 - val_accuracy: 0.9890
# Epoch 20/100
# 364/364 [==============================] - 0s 693us/step - loss: 0.0652 - accuracy: 0.9808 - val_loss: 0.0592 - val_accuracy: 0.9890
# Epoch 21/100
# 364/364 [==============================] - 0s 694us/step - loss: 0.0645 - accuracy: 0.9835 - val_loss: 0.0587 - val_accuracy: 0.9890
# Epoch 22/100
# 364/364 [==============================] - 0s 686us/step - loss: 0.0639 - accuracy: 0.9890 - val_loss: 0.0581 - val_accuracy: 0.9890
# Epoch 23/100
# 364/364 [==============================] - 0s 697us/step - loss: 0.0634 - accuracy: 0.9863 - val_loss: 0.0576 - val_accuracy: 0.9890
# Epoch 24/100
# 364/364 [==============================] - 0s 678us/step - loss: 0.0628 - accuracy: 0.9890 - val_loss: 0.0573 - val_accuracy: 0.9890
# Epoch 25/100
# 364/364 [==============================] - 0s 698us/step - loss: 0.0623 - accuracy: 0.9835 - val_loss: 0.0570 - val_accuracy: 0.9890
# Epoch 26/100
# 364/364 [==============================] - 0s 691us/step - loss: 0.0618 - accuracy: 0.9890 - val_loss: 0.0565 - val_accuracy: 0.9890
# Epoch 27/100
# 364/364 [==============================] - 0s 691us/step - loss: 0.0614 - accuracy: 0.9890 - val_loss: 0.0563 - val_accuracy: 0.9890
# Epoch 28/100
# 364/364 [==============================] - 0s 681us/step - loss: 0.0610 - accuracy: 0.9890 - val_loss: 0.0561 - val_accuracy: 0.9890
# Epoch 29/100
# 364/364 [==============================] - 0s 695us/step - loss: 0.0605 - accuracy: 0.9890 - val_loss: 0.0556 - val_accuracy: 0.9890
# Epoch 30/100
# 364/364 [==============================] - 0s 687us/step - loss: 0.0601 - accuracy: 0.9890 - val_loss: 0.0552 - val_accuracy: 0.9890
# Epoch 31/100
# 364/364 [==============================] - 0s 694us/step - loss: 0.0598 - accuracy: 0.9890 - val_loss: 0.0549 - val_accuracy: 0.9890
# Epoch 32/100
# 364/364 [==============================] - 0s 699us/step - loss: 0.0594 - accuracy: 0.9863 - val_loss: 0.0548 - val_accuracy: 0.9890
# Epoch 33/100
# 364/364 [==============================] - 0s 664us/step - loss: 0.0591 - accuracy: 0.9890 - val_loss: 0.0547 - val_accuracy: 0.9890
# Epoch 34/100
# 364/364 [==============================] - 0s 688us/step - loss: 0.0588 - accuracy: 0.9890 - val_loss: 0.0544 - val_accuracy: 0.9890
# Epoch 35/100
# 364/364 [==============================] - 0s 668us/step - loss: 0.0585 - accuracy: 0.9890 - val_loss: 0.0542 - val_accuracy: 0.9890
# Epoch 36/100
# 364/364 [==============================] - 0s 687us/step - loss: 0.0582 - accuracy: 0.9890 - val_loss: 0.0540 - val_accuracy: 0.9890
# Epoch 37/100
# 364/364 [==============================] - 0s 679us/step - loss: 0.0578 - accuracy: 0.9890 - val_loss: 0.0539 - val_accuracy: 0.9890
# Epoch 38/100
# 364/364 [==============================] - 0s 667us/step - loss: 0.0576 - accuracy: 0.9890 - val_loss: 0.0538 - val_accuracy: 0.9890
# Epoch 39/100
# 364/364 [==============================] - 0s 681us/step - loss: 0.0573 - accuracy: 0.9890 - val_loss: 0.0535 - val_accuracy: 0.9890
# Epoch 40/100
# 364/364 [==============================] - 0s 675us/step - loss: 0.0571 - accuracy: 0.9890 - val_loss: 0.0533 - val_accuracy: 0.9890
# Epoch 41/100
# 364/364 [==============================] - 0s 672us/step - loss: 0.0569 - accuracy: 0.9890 - val_loss: 0.0532 - val_accuracy: 0.9890
# Epoch 42/100
# 364/364 [==============================] - 0s 672us/step - loss: 0.0566 - accuracy: 0.9890 - val_loss: 0.0529 - val_accuracy: 0.9890
# Epoch 43/100
# 364/364 [==============================] - 0s 682us/step - loss: 0.0564 - accuracy: 0.9890 - val_loss: 0.0529 - val_accuracy: 0.9890
# Epoch 44/100
# 364/364 [==============================] - 0s 706us/step - loss: 0.0562 - accuracy: 0.9890 - val_loss: 0.0530 - val_accuracy: 0.9890
# Epoch 45/100
# 364/364 [==============================] - 0s 696us/step - loss: 0.0559 - accuracy: 0.9890 - val_loss: 0.0528 - val_accuracy: 0.9890
# Epoch 46/100
# 364/364 [==============================] - 0s 689us/step - loss: 0.0558 - accuracy: 0.9890 - val_loss: 0.0528 - val_accuracy: 0.9890
# Epoch 47/100
# 364/364 [==============================] - 0s 679us/step - loss: 0.0556 - accuracy: 0.9890 - val_loss: 0.0527 - val_accuracy: 0.9890
# Epoch 48/100
# 364/364 [==============================] - 0s 664us/step - loss: 0.0554 - accuracy: 0.9890 - val_loss: 0.0526 - val_accuracy: 0.9890
# Epoch 49/100
# 364/364 [==============================] - 0s 678us/step - loss: 0.0551 - accuracy: 0.9890 - val_loss: 0.0523 - val_accuracy: 0.9890
# Epoch 50/100
# 364/364 [==============================] - 0s 689us/step - loss: 0.0550 - accuracy: 0.9890 - val_loss: 0.0523 - val_accuracy: 0.9890
# Epoch 51/100
# 364/364 [==============================] - 0s 681us/step - loss: 0.0548 - accuracy: 0.9890 - val_loss: 0.0521 - val_accuracy: 0.9890
# Epoch 52/100
# 364/364 [==============================] - 0s 704us/step - loss: 0.0546 - accuracy: 0.9890 - val_loss: 0.0521 - val_accuracy: 0.9890
# Epoch 53/100
# 364/364 [==============================] - 0s 686us/step - loss: 0.0545 - accuracy: 0.9890 - val_loss: 0.0520 - val_accuracy: 0.9890
# Epoch 54/100
# 364/364 [==============================] - 0s 694us/step - loss: 0.0543 - accuracy: 0.9890 - val_loss: 0.0520 - val_accuracy: 0.9890
# Epoch 55/100
# 364/364 [==============================] - 0s 682us/step - loss: 0.0541 - accuracy: 0.9890 - val_loss: 0.0519 - val_accuracy: 0.9890
# Epoch 56/100
# 364/364 [==============================] - 0s 686us/step - loss: 0.0540 - accuracy: 0.9890 - val_loss: 0.0518 - val_accuracy: 0.9890
# Epoch 57/100
# 364/364 [==============================] - 0s 702us/step - loss: 0.0538 - accuracy: 0.9890 - val_loss: 0.0517 - val_accuracy: 0.9890
# Epoch 58/100
# 364/364 [==============================] - 0s 682us/step - loss: 0.0537 - accuracy: 0.9890 - val_loss: 0.0516 - val_accuracy: 0.9890
# Epoch 59/100
# 364/364 [==============================] - 0s 699us/step - loss: 0.0535 - accuracy: 0.9890 - val_loss: 0.0514 - val_accuracy: 0.9890
# Epoch 60/100
# 364/364 [==============================] - 0s 700us/step - loss: 0.0534 - accuracy: 0.9890 - val_loss: 0.0513 - val_accuracy: 0.9890
# Epoch 61/100
# 364/364 [==============================] - 0s 673us/step - loss: 0.0533 - accuracy: 0.9890 - val_loss: 0.0514 - val_accuracy: 0.9890
# Epoch 62/100
# 364/364 [==============================] - 0s 675us/step - loss: 0.0532 - accuracy: 0.9890 - val_loss: 0.0513 - val_accuracy: 0.9890
# Epoch 63/100
# 364/364 [==============================] - 0s 675us/step - loss: 0.0530 - accuracy: 0.9890 - val_loss: 0.0513 - val_accuracy: 0.9890
# Epoch 64/100
# 364/364 [==============================] - 0s 726us/step - loss: 0.0529 - accuracy: 0.9890 - val_loss: 0.0513 - val_accuracy: 0.9890
# Epoch 65/100
# 364/364 [==============================] - 0s 667us/step - loss: 0.0528 - accuracy: 0.9890 - val_loss: 0.0513 - val_accuracy: 0.9890
# Epoch 66/100
# 364/364 [==============================] - 0s 658us/step - loss: 0.0526 - accuracy: 0.9890 - val_loss: 0.0512 - val_accuracy: 0.9890
# Epoch 67/100
# 364/364 [==============================] - 0s 680us/step - loss: 0.0525 - accuracy: 0.9890 - val_loss: 0.0511 - val_accuracy: 0.9890
# Epoch 68/100
# 364/364 [==============================] - 0s 666us/step - loss: 0.0524 - accuracy: 0.9890 - val_loss: 0.0510 - val_accuracy: 0.9890
# Epoch 69/100
# 364/364 [==============================] - 0s 663us/step - loss: 0.0523 - accuracy: 0.9890 - val_loss: 0.0510 - val_accuracy: 0.9890
# Epoch 70/100
# 364/364 [==============================] - 0s 664us/step - loss: 0.0521 - accuracy: 0.9890 - val_loss: 0.0509 - val_accuracy: 0.9780
# Epoch 71/100
# 364/364 [==============================] - 0s 678us/step - loss: 0.0520 - accuracy: 0.9890 - val_loss: 0.0511 - val_accuracy: 0.9890
# Epoch 72/100
# 364/364 [==============================] - 0s 667us/step - loss: 0.0520 - accuracy: 0.9890 - val_loss: 0.0510 - val_accuracy: 0.9780
# Epoch 73/100
# 364/364 [==============================] - 0s 662us/step - loss: 0.0518 - accuracy: 0.9890 - val_loss: 0.0510 - val_accuracy: 0.9780
# Epoch 74/100
# 364/364 [==============================] - 0s 666us/step - loss: 0.0517 - accuracy: 0.9890 - val_loss: 0.0511 - val_accuracy: 0.9780
# Epoch 75/100
# 364/364 [==============================] - 0s 661us/step - loss: 0.0516 - accuracy: 0.9890 - val_loss: 0.0512 - val_accuracy: 0.9780
# Epoch 76/100
# 364/364 [==============================] - 0s 698us/step - loss: 0.0515 - accuracy: 0.9890 - val_loss: 0.0512 - val_accuracy: 0.9780
# Epoch 77/100
# 364/364 [==============================] - 0s 681us/step - loss: 0.0514 - accuracy: 0.9890 - val_loss: 0.0512 - val_accuracy: 0.9780
# Epoch 78/100
# 364/364 [==============================] - 0s 648us/step - loss: 0.0513 - accuracy: 0.9890 - val_loss: 0.0510 - val_accuracy: 0.9780
# Epoch 79/100
# 364/364 [==============================] - 0s 675us/step - loss: 0.0513 - accuracy: 0.9890 - val_loss: 0.0509 - val_accuracy: 0.9780
# Epoch 80/100
# 364/364 [==============================] - 0s 686us/step - loss: 0.0512 - accuracy: 0.9890 - val_loss: 0.0510 - val_accuracy: 0.9780
# Epoch 81/100
# 364/364 [==============================] - 0s 678us/step - loss: 0.0511 - accuracy: 0.9890 - val_loss: 0.0510 - val_accuracy: 0.9780
# Epoch 82/100
# 364/364 [==============================] - 0s 667us/step - loss: 0.0510 - accuracy: 0.9890 - val_loss: 0.0511 - val_accuracy: 0.9780
# Epoch 83/100
# 364/364 [==============================] - 0s 667us/step - loss: 0.0508 - accuracy: 0.9890 - val_loss: 0.0512 - val_accuracy: 0.9780
# Epoch 84/100
# 364/364 [==============================] - 0s 700us/step - loss: 0.0508 - accuracy: 0.9890 - val_loss: 0.0511 - val_accuracy: 0.9780
# Epoch 85/100
# 364/364 [==============================] - 0s 650us/step - loss: 0.0507 - accuracy: 0.9890 - val_loss: 0.0509 - val_accuracy: 0.9780
# Epoch 86/100
# 364/364 [==============================] - 0s 691us/step - loss: 0.0506 - accuracy: 0.9890 - val_loss: 0.0509 - val_accuracy: 0.9780
# Epoch 87/100
# 364/364 [==============================] - 0s 675us/step - loss: 0.0504 - accuracy: 0.9890 - val_loss: 0.0507 - val_accuracy: 0.9780
# Epoch 88/100
# 364/364 [==============================] - 0s 673us/step - loss: 0.0505 - accuracy: 0.9890 - val_loss: 0.0508 - val_accuracy: 0.9780
# Epoch 89/100
# 364/364 [==============================] - 0s 667us/step - loss: 0.0504 - accuracy: 0.9890 - val_loss: 0.0508 - val_accuracy: 0.9780
# Epoch 90/100
# 364/364 [==============================] - 0s 681us/step - loss: 0.0503 - accuracy: 0.9890 - val_loss: 0.0509 - val_accuracy: 0.9780
# Epoch 91/100
# 364/364 [==============================] - 0s 656us/step - loss: 0.0502 - accuracy: 0.9890 - val_loss: 0.0510 - val_accuracy: 0.9780
# Epoch 92/100
# 364/364 [==============================] - 0s 679us/step - loss: 0.0501 - accuracy: 0.9890 - val_loss: 0.0509 - val_accuracy: 0.9780
# Epoch 93/100
# 364/364 [==============================] - 0s 691us/step - loss: 0.0501 - accuracy: 0.9890 - val_loss: 0.0510 - val_accuracy: 0.9780
# Epoch 94/100
# 364/364 [==============================] - 0s 664us/step - loss: 0.0500 - accuracy: 0.9890 - val_loss: 0.0510 - val_accuracy: 0.9780
# Epoch 95/100
# 364/364 [==============================] - 0s 684us/step - loss: 0.0499 - accuracy: 0.9890 - val_loss: 0.0510 - val_accuracy: 0.9780
# Epoch 96/100
# 364/364 [==============================] - 0s 693us/step - loss: 0.0497 - accuracy: 0.9890 - val_loss: 0.0507 - val_accuracy: 0.9780
# Epoch 97/100
# 364/364 [==============================] - 0s 677us/step - loss: 0.0498 - accuracy: 0.9890 - val_loss: 0.0508 - val_accuracy: 0.9780
# Epoch 98/100
# 364/364 [==============================] - 0s 675us/step - loss: 0.0497 - accuracy: 0.9890 - val_loss: 0.0508 - val_accuracy: 0.9780
# Epoch 99/100
# 364/364 [==============================] - 0s 677us/step - loss: 0.0497 - accuracy: 0.9890 - val_loss: 0.0508 - val_accuracy: 0.9780
# Epoch 100/100
# 364/364 [==============================] - 0s 679us/step - loss: 0.0496 - accuracy: 0.9890 - val_loss: 0.0509 - val_accuracy: 0.9780
